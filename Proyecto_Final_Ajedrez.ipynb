# %%
def menu_aperturas():
    print("Bienvenido al programa de aperturas de ajedrez, que apertura deseas seleccionar?: ")
    print("1. Sistema de Londres")
    print("2. Caro-Kann")
    print("3. Gambito de Dama")
    print("4.Salir")
    opcion = int(input("Elija una opción (1-4): "))
    return opcion

def londres_sistema(posicion_actual, movimiento_numero, tablero):
    if movimiento_numero == 1:
        if posicion_actual == "d4":
            siguiente_movimiento = "d5"
            movimiento_numero += 1
            tablero[6][3] = "-"
            tablero[4][3] = "p"
            tablero[1][3] = "-"
            tablero[3][3] = "P"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 2:
        if posicion_actual == "Nf3":
            siguiente_movimiento = "Nf6"
            movimiento_numero += 1
            tablero[7][6] = "-"
            tablero[5][5] = "n"
            tablero[0][6] = "-"
            tablero[2][5] = "N"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 3:
        if posicion_actual == "Bf4":
            siguiente_movimiento = "e6"
            movimiento_numero += 1
            tablero[7][2] = "-"
            tablero[4][5] = "b"
            tablero[1][4] = "-"
            tablero[2][4] = "P"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 4:
        if posicion_actual == "e3":
            siguiente_movimiento = "c5"
            movimiento_numero += 1
            tablero[6][4] = "-"
            tablero[5][4] = "p"
            tablero[1][2] = "-"
            tablero[3][2] = "P"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 5:
        if posicion_actual == "c3":
            siguiente_movimiento = "Nc6"
            movimiento_numero += 1
            tablero[6][2] = "-"
            tablero[5][2] = "p"
            tablero[0][1] = "-"
            tablero[2][2] = "N"
        elif posicion_actual == "dxc5":
            siguiente_movimiento = "Bxc5"
            movimiento_numero += 1
            tablero[4][3] = "-"
            tablero[3][2] = "B"
            tablero[0][5] = "-"
            
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    else:
        siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    print("Las piezas negras han jugado con: ", siguiente_movimiento)
    print_tablero(tablero)
    return movimiento_numero, tablero
def caro_kann(posicion_actual, movimiento_numero, tablero):
    if movimiento_numero == 1:
        if posicion_actual == "c6":
            siguiente_movimiento = "d4"
            movimiento_numero += 1
            tablero[6][4] = "-"
            tablero[4][4] = "p"
            tablero[1][2] = "-"
            tablero[2][2] = "P"
            tablero[6][3] = "-"
            tablero[4][3] = "p"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 2:
        if posicion_actual == "d5":
            siguiente_movimiento = "Nc3"
            movimiento_numero += 1
            tablero[1][3] = "-"
            tablero[3][3] = "P"
            tablero[7][1] = "-"
            tablero[5][2] = "n"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 3:
        if posicion_actual == "dxe4":
            siguiente_movimiento = "Nxe4"
            movimiento_numero += 1
            tablero[5][2] = "-"
            tablero[4][4] = "n"
            tablero[3][3] = "-"
            
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 4:
        if posicion_actual == "Bf5":
            siguiente_movimiento = "Nc5"
            movimiento_numero += 1
            tablero[0][2] = "-"
            tablero[3][5] = "B"
            tablero[4][4] = "-"
            tablero[3][2] = "n"
        elif posicion_actual == "Nf6":
            siguiente_movimiento = "Nxf6+ y por el jaque exf6"
            movimiento_numero += 1
            tablero[4][4] = "-"
            tablero[2][5] = "P"
            tablero[0][6] = "-"
            tablero[1][4] = "-"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    else:
        siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    print("Las piezas blancas han jugado con: ", siguiente_movimiento)
    print_tablero(tablero)
    return movimiento_numero, tablero
def gambito_dama(posicion_actual, movimiento_numero, tablero):
    if movimiento_numero == 1:
        if posicion_actual == "d4":
            siguiente_movimiento = "d5"
            movimiento_numero += 1
            tablero[6][3] = "-"
            tablero[4][3] = "p"
            tablero[1][3] = "-"
            tablero[3][3] = "P"
            print("Cabe aclarar que este es el gambito aceptado, si quieres ver la variacion del gambito de dama declinado, el movimiento debe ser 'c4-'")
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 2:
        
        if posicion_actual == "c4":
            siguiente_movimiento = "dxc4"
            movimiento_numero += 1
            tablero[6][2] = "-"
            tablero[4][2] = "P"
            tablero[3][3] = "-"
        elif posicion_actual == "c4-":
            siguiente_movimiento = "e6"
            movimiento_numero = 6
            tablero[1][4] = "-"
            tablero[2][4] = "P"
            tablero[6][2] = "-"
            tablero[4][2] = "p"
            
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 3:
        if posicion_actual == "Nf3":
            siguiente_movimiento = "Nf6"
            movimiento_numero += 1
            tablero[7][6] = "-"
            tablero[5][5] = "n"
            tablero[0][6] = "-"
            tablero[2][5] = "N"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 4:
        if posicion_actual == "e3":
            siguiente_movimiento = "e6"
            movimiento_numero += 1
            tablero[6][4] = "-"
            tablero[5][4] = "p"
            tablero[1][4] = "-"
            tablero[2][4] = "P"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    elif movimiento_numero == 5:
        if posicion_actual == "Bxc4":
            siguiente_movimiento = "c5"
            movimiento_numero += 1
            tablero[7][5] = "-"
            tablero[4][2] = "B"
            tablero[1][2] = "-"
            tablero[3][2] = "P"
        else:
            siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    else:
        siguiente_movimiento = "Ese movimiento no es válido para esta apertura, intentalo de nuevo"
    print("Las piezas negras han jugado con: ", siguiente_movimiento)
    print_tablero(tablero)
    return movimiento_numero, tablero



def print_tablero(tablero):
  for fila in tablero:
    print(" ".join(fila))

def iniciar_tablero():
    tablero = [["R", "N", "B", "Q", "K", "B", "N", "R"],
               ["P", "P", "P", "P", "P", "P", "P", "P"],
               ["-", "-", "-", "-", "-", "-", "-", "-"],
               ["-", "-", "-", "-", "-", "-", "-", "-"],
               ["-", "-", "-", "-", "-", "-", "-", "-"],
               ["-", "-", "-", "-", "-", "-", "-", "-"],
               ["p", "p", "p", "p", "p", "p", "p", "p"],
               ["r", "n", "b", "q", "k", "b", "n", "r"]]
    return tablero
opcion = menu_aperturas()
if opcion == 1:
    print("Has elegido El Sistema de Londres!\n")
    movimiento_numero = 1
    tablero = iniciar_tablero()
    posicion_actual = input("Que movimiento deseas realizar?: ")
    while True:
        movimiento_numero, tablero = londres_sistema(posicion_actual, movimiento_numero, tablero)
        if movimiento_numero > 5:
            print("Felicidades, has logrado terminar con la apertura del sistema de Londres, si quieres aprender mas sobre las variantes de esta apertura puedes leer el libro 'Aperturas Modernas de Ajedrez' de Richard Griffith.")
            break
        posicion_actual = input("Que movimiento deseas realizar?: ")
elif opcion == 2:
    print("Has elegido la Caro-Kann!\n")
    print("El movimiento de las blancas es: e4")
    movimiento_numero = 1
    tablero = iniciar_tablero()
    posicion_actual = input("Que movimiento deseas realizar?: ")
    while True:
        movimiento_numero, tablero = caro_kann(posicion_actual, movimiento_numero, tablero)
        if movimiento_numero > 4:
            print("Felicidades, has logrado terminar con la apertura Caro-Kann, si quieres aprender mas sobre las variantes de esta apertura puedes leer el libro 'Aperturas Modernas de Ajedrez' de Richard Griffith.")
            break
        posicion_actual = input("Que movimiento deseas realizar?: ")
elif opcion == 3:
    print("Has elegido El Gambito de Dama!\n")
    movimiento_numero = 1
    tablero = iniciar_tablero()
    posicion_actual = input("Que movimiento deseas realizar?: ")
    while True:
        movimiento_numero, tablero = gambito_dama(posicion_actual, movimiento_numero, tablero)
        if movimiento_numero > 5:
            print("Felicidades, has logrado terminar con el gambito de dama, si quieres aprender mas sobre las variantes de esta apertura puedes leer el libro 'Aperturas Modernas de Ajedrez' de Richard Griffith.")
            break
        posicion_actual = input("Que movimiento deseas realizar?: ")

elif opcion == 4:
    print('Saliendo')
else:
    print("Opción no válida.")
# Out:
# Bienvenido al programa de aperturas de ajedrez, que apertura deseas seleccionar?:
# 1. Sistema de Londres
# 2. Caro-Kann
# 3. Gambito de Dama
# 4.Salir
# Elija una opción (1-4): 3
# Has elegido El Gambito de Dama!
#
# Cabe clarar que este es el gambito de dama aceptado, por lo tanto ..
#
# Que movimiento deseas realizar?: d4
# Si quieres ver la variacion del gambito de dama declinado, el movimiento debe ser 'c4-'
# Las piezas negras han jugado con:  d5
# R N B Q K B N R
# P P P - P P P P
# - - - - - - - -
# - - - P - - - -
# - - - p - - - -
# - - - - - - - -
# p p p - p p p p
# r n b q k b n r
# Que movimiento deseas realizar?: c4-
# Las piezas negras han jugado con:  e6
# R N B Q K B N R
# P P P - - P P P
# - - - - P - - -
# - - - P - - - -
# - - p p - - - -
# - - - - - - - -
# p p - - p p p p
# r n b q k b n r
# ...
